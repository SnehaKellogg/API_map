# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm
from datetime import date

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
recordedcity= []
temp = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
maxtemp = []
wind = []

n = 1
# Running in loop for all the cities recorded
for city in cities:
    # building query url
    parameters = {'q': city, 'appid': api_key, "units": "metric", 'lang': 'es'}
    response = requests.get(url, params = parameters).json()
    # Exracting info from response
    try:
        temp.append(response['main']['temp'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        recordedcity.append(response['name'])
        #datetext.append(response['list']['dt_txt'])
        humidity.append(response['main']['humidity'])
        maxtemp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])   
        # Printing response
        print(f"Processing Record {n} of {len(cities)} | {city}")
        #creating lag to avoid blocking of API key
        time.sleep(0.5)
        # moving to next 
        n = n + 1
        # handling exception
    except KeyError:
        print("Is the city real! Skipping it, sorry")
        n = n+1

# #need to add code for "Data retrieval complete" and time lapse after every 10 may be
# Out:
# Processing Record 1 of 624 | usolye
# Is the city real! Skipping it, sorry
# Processing Record 3 of 624 | busselton
# Processing Record 4 of 624 | tuktoyaktuk
# Processing Record 5 of 624 | smidovich
# Processing Record 6 of 624 | mount darwin
# Processing Record 7 of 624 | victoria
# Processing Record 8 of 624 | punta arenas
# Processing Record 9 of 624 | jamestown
# Processing Record 10 of 624 | namibe
# Processing Record 11 of 624 | thompson
# Is the city real! Skipping it, sorry
# Processing Record 13 of 624 | rikitea
# Processing Record 14 of 624 | saskylakh
# Processing Record 15 of 624 | gigmoto
# Processing Record 16 of 624 | kodiak
# Processing Record 17 of 624 | gillette
# Is the city real! Skipping it, sorry
# Processing Record 19 of 624 | monrovia
# Processing Record 20 of 624 | neuquen
# Processing Record 21 of 624 | kuandian
# Processing Record 22 of 624 | atuona
# Processing Record 23 of 624 | alugan
# Processing Record 24 of 624 | havelock
# Processing Record 25 of 624 | albany
# Processing Record 26 of 624 | saint-louis
# Processing Record 27 of 624 | jumla
# Processing Record 28 of 624 | avarua
# Is the city real! Skipping it, sorry
# Processing Record 30 of 624 | osypenko
# Processing Record 31 of 624 | kruisfontein
# Processing Record 32 of 624 | bluff
# Processing Record 33 of 624 | port lincoln
# Is the city real! Skipping it, sorry
# Processing Record 35 of 624 | berlevag
# Processing Record 36 of 624 | kalabo
# Processing Record 37 of 624 | kapaa
# Processing Record 38 of 624 | biak
# Is the city real! Skipping it, sorry
# Processing Record 40 of 624 | nha trang
# Processing Record 41 of 624 | mogadishu
# Is the city real! Skipping it, sorry
# Processing Record 43 of 624 | xining
# Processing Record 44 of 624 | katsuura
# Processing Record 45 of 624 | paamiut
# Processing Record 46 of 624 | mahebourg
# Processing Record 47 of 624 | ribeira grande
# Processing Record 48 of 624 | pondicherry
# Processing Record 49 of 624 | granados
# Processing Record 50 of 624 | butaritari
# Processing Record 51 of 624 | nanortalik
# Processing Record 52 of 624 | provideniya
# Processing Record 53 of 624 | pacific grove
# Processing Record 54 of 624 | biabou
# Processing Record 55 of 624 | pastavy
# Processing Record 56 of 624 | praia
# Processing Record 57 of 624 | mataura
# Processing Record 58 of 624 | tasiilaq
# Processing Record 59 of 624 | barrow
# Processing Record 60 of 624 | ushuaia
# Processing Record 61 of 624 | nikolskoye
# Processing Record 62 of 624 | souillac
# Processing Record 63 of 624 | lagoa
# Processing Record 64 of 624 | kutum
# Processing Record 65 of 624 | shingu
# Processing Record 66 of 624 | pevek
# Processing Record 67 of 624 | kahului
# Processing Record 68 of 624 | esperance
# Processing Record 69 of 624 | georgetown
# Processing Record 70 of 624 | hobart
# Processing Record 71 of 624 | marfino
# Processing Record 72 of 624 | vaini
# Processing Record 73 of 624 | porto novo
# Processing Record 74 of 624 | port alfred
# Processing Record 75 of 624 | upernavik
# Processing Record 76 of 624 | hermanus
# Is the city real! Skipping it, sorry
# Is the city real! Skipping it, sorry
# Processing Record 79 of 624 | carnarvon
# Processing Record 80 of 624 | colomi
# Processing Record 81 of 624 | mount gambier
# Processing Record 82 of 624 | codrington
# Processing Record 83 of 624 | puerto ayora
# Processing Record 84 of 624 | bredasdorp
# Processing Record 85 of 624 | lebu
# Processing Record 86 of 624 | khatanga
# Processing Record 87 of 624 | russell
# Processing Record 88 of 624 | cherskiy
# Processing Record 89 of 624 | caravelas
# Is the city real! Skipping it, sorry
# Processing Record 91 of 624 | antalaha
# Processing Record 92 of 624 | iralaya
# Processing Record 93 of 624 | castro
# Processing Record 94 of 624 | hilo
# Processing Record 95 of 624 | sao filipe
# Processing Record 96 of 624 | guerrero negro
# Processing Record 97 of 624 | kindu
# Processing Record 98 of 624 | pingliang
# Processing Record 99 of 624 | acapulco
# Processing Record 100 of 624 | kokorevka
# Processing Record 101 of 624 | hithadhoo
# Processing Record 102 of 624 | arecibo
# Is the city real! Skipping it, sorry
# Is the city real! Skipping it, sorry
# Is the city real! Skipping it, sorry
# Processing Record 106 of 624 | sinnamary
# Is the city real! Skipping it, sorry
# Processing Record 108 of 624 | islamkot
# Processing Record 109 of 624 | hasaki
# Processing Record 110 of 624 | forlimpopoli
# Processing Record 111 of 624 | saldanha
# Processing Record 112 of 624 | klaksvik
# Processing Record 113 of 624 | cabo san lucas
# Processing Record 114 of 624 | daru
# Is the city real! Skipping it, sorry
# Processing Record 116 of 624 | torbay
# Processing Record 117 of 624 | bambous virieux
# Processing Record 118 of 624 | chake chake
# Processing Record 119 of 624 | severo-kurilsk
# Processing Record 120 of 624 | kudahuvadhoo
# Processing Record 121 of 624 | ponta do sol
# Is the city real! Skipping it, sorry
# Processing Record 123 of 624 | the valley
# Processing Record 124 of 624 | novikovo
# Processing Record 125 of 624 | lacolle
# Processing Record 126 of 624 | vestmanna
# Processing Record 127 of 624 | airai
# Processing Record 128 of 624 | broken hill
# Processing Record 129 of 624 | new norfolk
# Processing Record 130 of 624 | camopi
# Processing Record 131 of 624 | praia da vitoria
# Processing Record 132 of 624 | santa rita do sapucai
# Is the city real! Skipping it, sorry
# Processing Record 134 of 624 | port hedland
# Processing Record 135 of 624 | narsaq
# Processing Record 136 of 624 | tateyama
# Processing Record 137 of 624 | poya
# Processing Record 138 of 624 | saint-philippe
# Processing Record 139 of 624 | kavaratti
# Processing Record 140 of 624 | dingle
# Processing Record 141 of 624 | cape town
# Processing Record 142 of 624 | seoul
# Processing Record 143 of 624 | constitucion
# Processing Record 144 of 624 | sitka
# Processing Record 145 of 624 | dolores
# Is the city real! Skipping it, sorry
# Processing Record 147 of 624 | cayenne
# Processing Record 148 of 624 | maamba
# Processing Record 149 of 624 | kety
# Processing Record 150 of 624 | yazykovo
# Is the city real! Skipping it, sorry
# Processing Record 152 of 624 | flinders
# Is the city real! Skipping it, sorry
# Processing Record 154 of 624 | adeje
# Processing Record 155 of 624 | chuy
# Processing Record 156 of 624 | honiara
# Processing Record 157 of 624 | mabaruma
# Processing Record 158 of 624 | leningradskiy
# Processing Record 159 of 624 | galich
# Processing Record 160 of 624 | san policarpo
# Processing Record 161 of 624 | lima
# Processing Record 162 of 624 | selma
# Processing Record 163 of 624 | ancud
# Is the city real! Skipping it, sorry
# Processing Record 165 of 624 | sal rei
# Processing Record 166 of 624 | rocha
# Processing Record 167 of 624 | alofi
# Processing Record 168 of 624 | sao joao da barra
# Processing Record 169 of 624 | vardo
# Is the city real! Skipping it, sorry
# Processing Record 171 of 624 | wajima
# Is the city real! Skipping it, sorry
# Processing Record 173 of 624 | tomatlan
# Processing Record 174 of 624 | billings
# Processing Record 175 of 624 | ulaanbaatar
# Processing Record 176 of 624 | ginir
# Processing Record 177 of 624 | port moresby
# Processing Record 178 of 624 | palauig
# Processing Record 179 of 624 | dharchula
# Processing Record 180 of 624 | camacha
# Processing Record 181 of 624 | amnat charoen
# Processing Record 182 of 624 | ilulissat
# Processing Record 183 of 624 | zabaykalsk
# Processing Record 184 of 624 | san patricio
# Processing Record 185 of 624 | viedma
# Processing Record 186 of 624 | ashtian
# Processing Record 187 of 624 | ambulu
# Processing Record 188 of 624 | cidreira
# Processing Record 189 of 624 | evensk
# Processing Record 190 of 624 | mayor pablo lagerenza
# Processing Record 191 of 624 | dunedin
# Processing Record 192 of 624 | monywa
# Processing Record 193 of 624 | longyearbyen
# Is the city real! Skipping it, sorry
# Processing Record 195 of 624 | dongsheng
# Processing Record 196 of 624 | merauke
# Processing Record 197 of 624 | hay river
# Processing Record 198 of 624 | labuhan
# Processing Record 199 of 624 | salair
# Processing Record 200 of 624 | yar-sale
# Processing Record 201 of 624 | pangnirtung
# Processing Record 202 of 624 | hovd
# Processing Record 203 of 624 | mankono
# Processing Record 204 of 624 | saint george
# Processing Record 205 of 624 | marsh harbour
# Processing Record 206 of 624 | alexandria
# Processing Record 207 of 624 | tiksi
# Processing Record 208 of 624 | naifaru
# Processing Record 209 of 624 | phan thiet
# Processing Record 210 of 624 | fare
# Processing Record 211 of 624 | borogontsy
# Processing Record 212 of 624 | suslovo
# Processing Record 213 of 624 | naryan-mar
# Processing Record 214 of 624 | dwarka
# Processing Record 215 of 624 | beihai
# Processing Record 216 of 624 | redlands
# Processing Record 217 of 624 | grand gaube
# Processing Record 218 of 624 | fort-shevchenko
# Processing Record 219 of 624 | ystad
# Processing Record 220 of 624 | beringovskiy
# Processing Record 221 of 624 | lodwar
# Processing Record 222 of 624 | vila
# Processing Record 223 of 624 | teya
# Processing Record 224 of 624 | saint-augustin
# Processing Record 225 of 624 | vila franca do campo
# Processing Record 226 of 624 | sur
# Processing Record 227 of 624 | ahipara
# Processing Record 228 of 624 | lavrentiya
# Processing Record 229 of 624 | salalah
# Is the city real! Skipping it, sorry
# Processing Record 231 of 624 | surt
# Processing Record 232 of 624 | yulara
# Processing Record 233 of 624 | hamilton
# Processing Record 234 of 624 | pyay
# Processing Record 235 of 624 | lorengau
# Processing Record 236 of 624 | muyuka
# Processing Record 237 of 624 | quatre cocos
# Processing Record 238 of 624 | ordzhonikidze
# Processing Record 239 of 624 | jiamusi
# Processing Record 240 of 624 | leshukonskoye
# Processing Record 241 of 624 | sovetskiy
# Processing Record 242 of 624 | bahia blanca
# Processing Record 243 of 624 | pozo colorado
# Is the city real! Skipping it, sorry
# Processing Record 245 of 624 | chapais
# Processing Record 246 of 624 | kuna
# Is the city real! Skipping it, sorry
# Processing Record 248 of 624 | mayo
# Processing Record 249 of 624 | poanas
# Is the city real! Skipping it, sorry
# Processing Record 251 of 624 | yaan
# Processing Record 252 of 624 | boende
# Processing Record 253 of 624 | russas
# Processing Record 254 of 624 | kirensk
# Processing Record 255 of 624 | jiayuguan
# Processing Record 256 of 624 | meulaboh
# Processing Record 257 of 624 | juan lacaze
# Processing Record 258 of 624 | maceio
# Processing Record 259 of 624 | avera
# Processing Record 260 of 624 | camacupa
# Processing Record 261 of 624 | banepa
# Processing Record 262 of 624 | aksu
# Processing Record 263 of 624 | bathsheba
# Processing Record 264 of 624 | freeport
# Processing Record 265 of 624 | oktyabrskoye
# Processing Record 266 of 624 | fortuna foothills
# Processing Record 267 of 624 | clyde river
# Processing Record 268 of 624 | nouadhibou
# Processing Record 269 of 624 | port macquarie
# Processing Record 270 of 624 | ostrovnoy
# Processing Record 271 of 624 | lompoc
# Processing Record 272 of 624 | east london
# Processing Record 273 of 624 | qaanaaq
# Processing Record 274 of 624 | tinskoy
# Processing Record 275 of 624 | vilyuysk
# Processing Record 276 of 624 | la rioja
# Is the city real! Skipping it, sorry
# Is the city real! Skipping it, sorry
# Processing Record 279 of 624 | dikson
# Processing Record 280 of 624 | rawson
# Processing Record 281 of 624 | verkhnevilyuysk
# Processing Record 282 of 624 | beruwala
# Processing Record 283 of 624 | touros
# Processing Record 284 of 624 | iqaluit
# Processing Record 285 of 624 | waingapu
# Processing Record 286 of 624 | komsomolskiy
# Processing Record 287 of 624 | lazaro cardenas
# Processing Record 288 of 624 | wanxian
# Processing Record 289 of 624 | san quintin
# Processing Record 290 of 624 | djibo
# Processing Record 291 of 624 | sundsvall
# Is the city real! Skipping it, sorry
# Is the city real! Skipping it, sorry
# Processing Record 294 of 624 | shizuishan
# Processing Record 295 of 624 | padang
# Processing Record 296 of 624 | shimoda
# Processing Record 297 of 624 | swan river
# Processing Record 298 of 624 | gaildorf
# Processing Record 299 of 624 | plettenberg bay
# Processing Record 300 of 624 | cimislia
# Processing Record 301 of 624 | capaci
# Is the city real! Skipping it, sorry
# Is the city real! Skipping it, sorry
# Processing Record 304 of 624 | mzimba
# Processing Record 305 of 624 | rohatyn
# Processing Record 306 of 624 | yellowknife
# Processing Record 307 of 624 | beaverlodge
# Processing Record 308 of 624 | salamiyah
# Processing Record 309 of 624 | priekule
# Processing Record 310 of 624 | bella vista
# Processing Record 311 of 624 | saint-georges
# Processing Record 312 of 624 | endicott
# Processing Record 313 of 624 | madimba
# Processing Record 314 of 624 | crailsheim
# Processing Record 315 of 624 | yerbogachen
# Processing Record 316 of 624 | kopavogur
# Processing Record 317 of 624 | plumlov
# Processing Record 318 of 624 | requena
# Processing Record 319 of 624 | niquelandia
# Processing Record 320 of 624 | arraial do cabo
# Is the city real! Skipping it, sorry
# Processing Record 322 of 624 | chimbote
# Processing Record 323 of 624 | anadyr
# Processing Record 324 of 624 | margate
# Processing Record 325 of 624 | marsa matruh
# Processing Record 326 of 624 | port-gentil
# Processing Record 327 of 624 | whitianga
# Is the city real! Skipping it, sorry
# Processing Record 329 of 624 | aklavik
# Processing Record 330 of 624 | brae
# Processing Record 331 of 624 | nicoya
# Processing Record 332 of 624 | severomorsk
# Processing Record 333 of 624 | lumeje
# Processing Record 334 of 624 | kaitangata
# Is the city real! Skipping it, sorry
# Processing Record 336 of 624 | gotsu
# Processing Record 337 of 624 | honningsvag
# Processing Record 338 of 624 | leo
# Processing Record 339 of 624 | roma
# Processing Record 340 of 624 | shaoxing
# Processing Record 341 of 624 | taoudenni
# Processing Record 342 of 624 | quesnel
# Is the city real! Skipping it, sorry
# Processing Record 344 of 624 | petropavl
# Processing Record 345 of 624 | hofn
# Processing Record 346 of 624 | faanui
# Is the city real! Skipping it, sorry
# Processing Record 348 of 624 | gurun
# Is the city real! Skipping it, sorry
# Processing Record 350 of 624 | brownwood
# Processing Record 351 of 624 | yining
# Is the city real! Skipping it, sorry
# Processing Record 353 of 624 | asosa
# Processing Record 354 of 624 | flin flon
# Processing Record 355 of 624 | coihaique
# Processing Record 356 of 624 | mehamn
# Processing Record 357 of 624 | kavieng
# Processing Record 358 of 624 | taltal
# Processing Record 359 of 624 | pisco
# Processing Record 360 of 624 | wadi maliz
# Processing Record 361 of 624 | madang
# Processing Record 362 of 624 | kochubey
# Processing Record 363 of 624 | bilma
# Processing Record 364 of 624 | tolaga bay
# Processing Record 365 of 624 | mar del plata
# Is the city real! Skipping it, sorry
# Processing Record 367 of 624 | bedburg
# Processing Record 368 of 624 | santa cruz
# Processing Record 369 of 624 | tefe
# Processing Record 370 of 624 | bilibino
# Processing Record 371 of 624 | develi
# Processing Record 372 of 624 | ust-kut
# Processing Record 373 of 624 | ucluelet
# Processing Record 374 of 624 | grants
# Processing Record 375 of 624 | araouane
# Processing Record 376 of 624 | kabarnet
# Processing Record 377 of 624 | talnakh
# Processing Record 378 of 624 | dzidzantun
# Processing Record 379 of 624 | akdagmadeni
# Processing Record 380 of 624 | minbu
# Processing Record 381 of 624 | vila velha
# Processing Record 382 of 624 | mindelo
# Processing Record 383 of 624 | jobner
# Processing Record 384 of 624 | arkadak
# Processing Record 385 of 624 | husavik
# Processing Record 386 of 624 | san rafael del sur
# Processing Record 387 of 624 | marica
# Is the city real! Skipping it, sorry
# Processing Record 389 of 624 | quzhou
# Processing Record 390 of 624 | matagami
# Is the city real! Skipping it, sorry
# Is the city real! Skipping it, sorry
# Processing Record 393 of 624 | santa isabel
# Processing Record 394 of 624 | goderich
# Processing Record 395 of 624 | tagusao
# Processing Record 396 of 624 | cam ranh
# Processing Record 397 of 624 | sibolga
# Processing Record 398 of 624 | muros
# Processing Record 399 of 624 | cockburn town
# Processing Record 400 of 624 | baruun-urt
# Processing Record 401 of 624 | keti bandar
# Processing Record 402 of 624 | pemberton
# Processing Record 403 of 624 | comodoro rivadavia
# Processing Record 404 of 624 | moron
# Processing Record 405 of 624 | nanakuli
# Processing Record 406 of 624 | manzhouli
# Processing Record 407 of 624 | cheremkhovo
# Is the city real! Skipping it, sorry
# Processing Record 409 of 624 | kondoa
# Processing Record 410 of 624 | gisborne
# Processing Record 411 of 624 | takoradi
# Processing Record 412 of 624 | katangli
# Processing Record 413 of 624 | chiang khong
# Processing Record 414 of 624 | kajaani
# Processing Record 415 of 624 | bulgan
# Processing Record 416 of 624 | karratha
# Processing Record 417 of 624 | kolda
# Processing Record 418 of 624 | arman
# Processing Record 419 of 624 | bethel
# Processing Record 420 of 624 | te anau
# Processing Record 421 of 624 | babylon
# Processing Record 422 of 624 | santa maria
# Processing Record 423 of 624 | tual
# Is the city real! Skipping it, sorry
# Processing Record 425 of 624 | emba
# Processing Record 426 of 624 | rawa mazowiecka
# Processing Record 427 of 624 | kieta
# Is the city real! Skipping it, sorry
# Is the city real! Skipping it, sorry
# Processing Record 430 of 624 | lekoni
# Processing Record 431 of 624 | antofagasta
# Processing Record 432 of 624 | poum
# Is the city real! Skipping it, sorry
# Processing Record 434 of 624 | puerto colombia
# Processing Record 435 of 624 | norman wells
# Processing Record 436 of 624 | havoysund
# Processing Record 437 of 624 | kozhva
# Processing Record 438 of 624 | mecca
# Processing Record 439 of 624 | luderitz
# Processing Record 440 of 624 | ahuimanu
# Is the city real! Skipping it, sorry
# Processing Record 442 of 624 | khiv
# Processing Record 443 of 624 | leh
# Processing Record 444 of 624 | namatanai
# Processing Record 445 of 624 | denpasar
# Processing Record 446 of 624 | coahuayana
# Processing Record 447 of 624 | san cristobal
# Processing Record 448 of 624 | miraflores
# Processing Record 449 of 624 | oskaloosa
# Processing Record 450 of 624 | bucerias
# Processing Record 451 of 624 | trelew
# Processing Record 452 of 624 | srednekolymsk
# Processing Record 453 of 624 | dandong
# Processing Record 454 of 624 | seymchan
# Processing Record 455 of 624 | mianyang
# Processing Record 456 of 624 | umm lajj
# Processing Record 457 of 624 | bereda
# Processing Record 458 of 624 | high level
# Processing Record 459 of 624 | phangnga
# Processing Record 460 of 624 | bam
# Processing Record 461 of 624 | san lorenzo de el escorial
# Processing Record 462 of 624 | sobolevo
# Processing Record 463 of 624 | oblivskaya
# Processing Record 464 of 624 | tobermory
# Processing Record 465 of 624 | sechura
# Is the city real! Skipping it, sorry
# Processing Record 467 of 624 | juneau
# Processing Record 468 of 624 | loukhi
# Processing Record 469 of 624 | port hardy
# Processing Record 470 of 624 | alekseyevsk
# Processing Record 471 of 624 | colares
# Processing Record 472 of 624 | benito juarez
# Processing Record 473 of 624 | talara
# Processing Record 474 of 624 | kuryk
# Processing Record 475 of 624 | la ronge
# Processing Record 476 of 624 | cururupu
# Processing Record 477 of 624 | sidi ali
# Processing Record 478 of 624 | teguldet
# Processing Record 479 of 624 | biloela
# Processing Record 480 of 624 | galle
# Is the city real! Skipping it, sorry
# Is the city real! Skipping it, sorry
# Processing Record 483 of 624 | chicama
# Processing Record 484 of 624 | carutapera
# Processing Record 485 of 624 | inhambane
# Processing Record 486 of 624 | tahoua
# Processing Record 487 of 624 | ukiah
# Processing Record 488 of 624 | almansa
# Is the city real! Skipping it, sorry
# Processing Record 490 of 624 | pangody
# Processing Record 491 of 624 | okha
# Processing Record 492 of 624 | agadez
# Processing Record 493 of 624 | kudat
# Is the city real! Skipping it, sorry
# Processing Record 495 of 624 | puerto escondido
# Processing Record 496 of 624 | fortuna
# Processing Record 497 of 624 | dom pedrito
# Processing Record 498 of 624 | tilichiki
# Processing Record 499 of 624 | medea
# Processing Record 500 of 624 | jalu
# Processing Record 501 of 624 | agua verde
# Processing Record 502 of 624 | tautira
# Processing Record 503 of 624 | portland
# Processing Record 504 of 624 | pierre
# Processing Record 505 of 624 | bahar
# Processing Record 506 of 624 | chekhov
# Processing Record 507 of 624 | olinda
# Processing Record 508 of 624 | nautla
# Processing Record 509 of 624 | katete
# Processing Record 510 of 624 | teguise
# Processing Record 511 of 624 | gat
# Processing Record 512 of 624 | katesh
# Processing Record 513 of 624 | kamenka
# Processing Record 514 of 624 | ugoofaaru
# Processing Record 515 of 624 | balkhash
# Processing Record 516 of 624 | morgan city
# Processing Record 517 of 624 | chokurdakh
# Processing Record 518 of 624 | darhan
# Processing Record 519 of 624 | port elizabeth
# Processing Record 520 of 624 | lovozero
# Processing Record 521 of 624 | iracoubo
# Processing Record 522 of 624 | zhezkazgan
# Is the city real! Skipping it, sorry
# Processing Record 524 of 624 | constanza
# Is the city real! Skipping it, sorry
# Processing Record 526 of 624 | sjovegan
# Is the city real! Skipping it, sorry
# Processing Record 528 of 624 | medianeira
# Processing Record 529 of 624 | otofuke
# Processing Record 530 of 624 | hami
# Processing Record 531 of 624 | dubti
# Processing Record 532 of 624 | karatau
# Processing Record 533 of 624 | itarantim
# Processing Record 534 of 624 | priiskovyy
# Processing Record 535 of 624 | volksrust
# Processing Record 536 of 624 | college station
# Processing Record 537 of 624 | ayan
# Processing Record 538 of 624 | semey
# Processing Record 539 of 624 | vuktyl
# Processing Record 540 of 624 | bungu
# Processing Record 541 of 624 | ngunguru
# Is the city real! Skipping it, sorry
# Processing Record 543 of 624 | ossora
# Processing Record 544 of 624 | south river
# Is the city real! Skipping it, sorry
# Processing Record 546 of 624 | fowa
# Processing Record 547 of 624 | thoen
# Processing Record 548 of 624 | maldonado
# Processing Record 549 of 624 | nieuw amsterdam
# Is the city real! Skipping it, sorry
# Is the city real! Skipping it, sorry
# Processing Record 552 of 624 | verkh-usugli
# Processing Record 553 of 624 | aleksandrov gay
# Processing Record 554 of 624 | puerto del rosario
# Processing Record 555 of 624 | manavalakurichi
# Processing Record 556 of 624 | ambilobe
# Processing Record 557 of 624 | tiarei
# Processing Record 558 of 624 | akureyri
# Processing Record 559 of 624 | luoyang
# Processing Record 560 of 624 | partizansk
# Processing Record 561 of 624 | pontes e lacerda
# Processing Record 562 of 624 | saurimo
# Processing Record 563 of 624 | termoli
# Processing Record 564 of 624 | bonthe
# Processing Record 565 of 624 | naze
# Is the city real! Skipping it, sorry
# Processing Record 567 of 624 | governador valadares
# Processing Record 568 of 624 | gornopravdinsk
# Processing Record 569 of 624 | anloga
# Is the city real! Skipping it, sorry
# Processing Record 571 of 624 | maragogi
# Processing Record 572 of 624 | nara
# Processing Record 573 of 624 | swan hill
# Processing Record 574 of 624 | angoche
# Processing Record 575 of 624 | washington
# Is the city real! Skipping it, sorry
# Processing Record 577 of 624 | karasjok
# Processing Record 578 of 624 | lata
# Processing Record 579 of 624 | novo aripuana
# Processing Record 580 of 624 | tsiroanomandidy
# Processing Record 581 of 624 | onguday
# Processing Record 582 of 624 | medeiros neto
# Processing Record 583 of 624 | hede
# Processing Record 584 of 624 | san joaquin
# Processing Record 585 of 624 | adrar
# Processing Record 586 of 624 | constantine
# Processing Record 587 of 624 | viesca
# Processing Record 588 of 624 | coquimbo
# Processing Record 589 of 624 | ngaoundere
# Processing Record 590 of 624 | trairi
# Processing Record 591 of 624 | leninsk
# Processing Record 592 of 624 | ligourion
# Processing Record 593 of 624 | kokopo
# Is the city real! Skipping it, sorry
# Processing Record 595 of 624 | emerald
# Processing Record 596 of 624 | akdepe
# Processing Record 597 of 624 | awjilah
# Processing Record 598 of 624 | sayyan
# Processing Record 599 of 624 | radcliff
# Processing Record 600 of 624 | luganville
# Processing Record 601 of 624 | tucuman
# Processing Record 602 of 624 | mysliborz
# Processing Record 603 of 624 | mandera
# Processing Record 604 of 624 | haines junction
# Processing Record 605 of 624 | mizdah
# Processing Record 606 of 624 | tiznit
# Processing Record 607 of 624 | churapcha
# Is the city real! Skipping it, sorry
# Processing Record 609 of 624 | grindavik
# Processing Record 610 of 624 | tornio
# Processing Record 611 of 624 | mapimi
# Processing Record 612 of 624 | wangaratta
# Processing Record 613 of 624 | vero beach
# Processing Record 614 of 624 | geraldton
# Processing Record 615 of 624 | vulcan
# Processing Record 616 of 624 | san antonio
# Processing Record 617 of 624 | talaya
# Processing Record 618 of 624 | moerai
# Processing Record 619 of 624 | dhidhdhoo
# Processing Record 620 of 624 | kysyl-syr
# Processing Record 621 of 624 | walvis bay
# Processing Record 622 of 624 | half moon bay
# Processing Record 623 of 624 | kenai
# Processing Record 624 of 624 | zhigansk

# %%
print(f"{len(recordedcity)} , {len(temp)}, {len(cloudiness)}, {len(country)}, {len(date)}, {len(humidity)}, {len(lat)}, {len(lng)}, {len(maxtemp)}, {len(wind)}")
# Out:
# 556 , 556, 556, 556, 556, 556, 556, 556, 556, 556

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": recordedcity,
    "Country": country,
    "Longitude": lng,
    "Latitude": lat,
    "Temperature": temp,
    "Cloudiness": cloudiness,
    "Datestamp": date,
    "Humidity": humidity,
    "Max Temperature": maxtemp,
    "Wind Speed": wind,
}
 
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#            City Country  Longitude  Latitude  Temperature  Cloudiness  \
# 0        Usolye      RU      56.68     59.42        -1.11          80
# 1     Busselton      AU     115.35    -33.64        15.13           0
# 2   Tuktoyaktuk      CA    -133.03     69.44        -5.00          75
# 3     Smidovich      RU     133.81     48.60        -1.87          64
# 4  Mount Darwin      ZW      31.58    -16.77        17.74           0
#
#     Datestamp  Humidity  Max Temperature  Wind Speed
# 0  1553474636        87            -1.11        1.34
# 1  1553474718        38            16.11        8.16
# 2  1553472000        79            -5.00        4.60
# 3  1553474880        60            -1.87        2.26
# 4  1553474880        87            17.74        1.86

# %%
weather_data.duplicated('City')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 526    False
# 527    False
# 528    False
# 529    False
# 530    False
# 531    False
# 532    False
# 533    False
# 534    False
# 535    False
# 536    False
# 537    False
# 538    False
# 539    False
# 540    False
# 541    False
# 542    False
# 543    False
# 544    False
# 545    False
# 546    False
# 547    False
# 548    False
# 549    False
# 550    False
# 551    False
# 552    False
# 553    False
# 554    False
# 555    False
# Length: 556, dtype: bool

# %%
weather_data.to_csv("weatherdata.csv")

# %%
#Pick the first date from dataframe
d = weather_data['Datestamp'][0]
#convert timestamp to date format
date = datetime.utcfromtimestamp(d)

#convert in format required for printing
record_date = date.strftime('%b-%d-%Y')
record_date
# Out:
# 'Mar-25-2019'

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather_data.plot(x='Latitude',y = 'Max Temperature', kind = 'scatter', title='City latitude vs Max Temperature (' + record_date + ')')
plt.savefig('Maxtemp_latitude.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
weather_data.plot(x='Latitude',y = 'Humidity', kind = 'scatter', title='City latitude vs Humidity (' + record_date + ')')

plt.savefig('Humidity_latitude.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
weather_data.plot(x='Latitude',y = 'Cloudiness', kind = 'scatter', title='City latitude vs Cloudiness ('+ record_date + ')')
plt.savefig('Cloudiness_latitude.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
weather_data.plot(x='Latitude',y = 'Wind Speed', kind = 'scatter', title='City latitude vs Wind Speed (' + record_date + ')')
plt.savefig('WindSpeed_latitude.png')
